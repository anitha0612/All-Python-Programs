# %%
import pandas as pd
data=pd.read_csv("songs.csv")
data
# Out:
#               artist                                    song  duration_ms  \
# 0     Britney Spears                  Oops!...I Did It Again       211160
# 1          blink-182                    All The Small Things       167066
# 2         Faith Hill                                 Breathe       250546
# 3           Bon Jovi                            It's My Life       224493
# 4             *NSYNC                             Bye Bye Bye       200560
# ...              ...                                     ...          ...
# 1995  Jonas Brothers                                  Sucker       181026
# 1996    Taylor Swift                            Cruel Summer       178426
# 1997    Blanco Brown                              The Git Up       200593
# 1998       Sam Smith  Dancing With A Stranger (with Normani)       171029
# 1999     Post Malone                                 Circles       215280
#
#       explicit  year  popularity  danceability  energy  key  loudness  mode  \
# ...

# %%
a=data[data["genre"]>"pop"]
a
# Out:
#                    artist                  song  duration_ms  explicit  year  \
# 1               blink-182  All The Small Things       167066     False  1999
# 2              Faith Hill               Breathe       250546     False  1999
# 3                Bon Jovi          It's My Life       224493     False  2000
# 7         Robbie Williams               Rock DJ       258560     False  2000
# 8         Destiny's Child           Say My Name       271333     False  1999
# ...                   ...                   ...          ...       ...   ...
# 1986                 Lauv       i'm so tired...       162582     False  2019
# 1988  Panic! At The Disco            High Hopes       190946     False  2018
# 1989           Marshmello       One Thing Right       181823     False  2019
# 1992              Normani            Motivation       193837     False  2019
# 1993           Joel Corry                 Sorry       188640     False  2019
#
# ...

# %%
b=a[a["popularity"]>83]
b
# Out:
#                  artist                                      song  \
# 1322  The Neighbourhood                           Sweater Weather
# 1326     Arctic Monkeys  Why'd You Only Call Me When You're High?
# 1344     Arctic Monkeys                          Do I Wanna Know?
# 1408        John Legend                                 All of Me
# 1511         The Weeknd                                 The Hills
# 1512  The Neighbourhood                              Daddy Issues
# 1514             Avicii                                The Nights
# 1613             WILLOW                            Wait a Minute!
# 1712      Billie Eilish                                     Bored
# 1819      Billie Eilish                      lovely (with Khalid)
# 1929      Billie Eilish                      lovely (with Khalid)
#
#       duration_ms  explicit  year  popularity  danceability  energy  key  \
# 1322       240400     False  2013          89         0.612   0.807   10
# ...

# %%
c=b[["year","popularity","genre"]]
c
# Out:
#       year  popularity                       genre
# 1322  2013          89                   rock, pop
# 1326  2013          84                        rock
# 1344  2013          84                        rock
# 1408  2013          84                    pop, R&B
# 1511  2015          84                    pop, R&B
# 1512  2015          85                   rock, pop
# 1514  2014          85       pop, Dance/Electronic
# 1613  2015          86  pop, R&B, Dance/Electronic
# 1712  2017          84       pop, Dance/Electronic
# 1819  2018          86       pop, Dance/Electronic
# 1929  2018          86       pop, Dance/Electronic

# %%
c.max()
# Out:
# year               2018
# popularity           89
# genre         rock, pop
# dtype: object
