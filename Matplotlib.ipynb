# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
x=np.array([9,14,49,32,27,45,14,20,38,49])
y=np.array([1,3,2,4,6,7,5,9,8,10])
plt.scatter(x,y)

# %%
b0=0.5
b1=0.7
e=1
yp=b0*b1*x+e
print(yp)
plt.scatter(x,y)
plt.plot(x,yp,c='crimson')
# Out:
# [ 4.15  5.9  18.15 12.2  10.45 16.75  5.9   8.   14.3  18.15]
